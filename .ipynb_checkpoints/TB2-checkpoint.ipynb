# %%
import networkx as nx
import matplotlib.pyplot as plt

g=nx.read_edgelist('facebook_combined.txt', create_using=nx.Graph(), nodetype=int)

print(nx.info(g))
# Out:
# Name:
# Type: Graph
# Number of nodes: 4039
# Number of edges: 88234
# Average degree:  43.6910

# %%
sp=nx.spring_layout(g)

plt.axis('off')

nx.draw_networkx(g,pos=sp, with_labels=False, node_size=35)
plt.show()

# %%
print(nx.average_shortest_path_length(g))
# Out:
# 3.6925068496963913

# %%
from networkx.algorithms import community
import itertools

comp = community.girvan_newman(g)
k = 2
print("xxx")
for communities in itertools.islice(comp, k):
    print("lll")
    print(tuple(sorted(c) for c in communities))
# Out:
# xxx
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-6990d030241b> in <module>()
#       5 k = 2
#       6 print("xxx")
# ----> 7 for communities in itertools.islice(comp, k):
#       8     print("lll")
#       9     print(tuple(sorted(c) for c in communities))
#
# ~\Anaconda3\lib\site-packages\networkx\algorithms\community\centrality.py in girvan_newman(G, most_valuable_edge)
#     152     g.remove_edges_from(nx.selfloop_edges(g))
#     153     while g.number_of_edges() > 0:
# --> 154         yield _without_most_central_edges(g, most_valuable_edge)
#     155
#     156
#
# ~\Anaconda3\lib\site-packages\networkx\algorithms\community\centrality.py in _without_most_central_edges(G, most_valuable_edge)
#     171     num_new_components = original_num_components
#     172     while num_new_components <= original_num_components:
# --> 173         edge = most_valuable_edge(G)
#     174         G.remove_edge(*edge)
#     175         new_components = tuple(nx.connected_components(G))
#
# ~\Anaconda3\lib\site-packages\networkx\algorithms\community\centrality.py in most_valuable_edge(G)
#     144             # We have guaranteed that the graph is non-empty, so this
#     145             # dictionary will never be empty.
# --> 146             betweenness = nx.edge_betweenness_centrality(G)
#     147             return max(betweenness, key=betweenness.get)
#     148     # The copy of G here must include the edge weight data.
#
# ~\Anaconda3\lib\site-packages\networkx\algorithms\centrality\betweenness.py in edge_betweenness_centrality(G, k, normalized, weight, seed)
#     202     # b[e]=0 for e in G.edges()
#     203     betweenness.update(dict.fromkeys(G.edges(), 0.0))
# --> 204     if k is None:
#     205         nodes = G
#     206     else:
#
# ~\Anaconda3\lib\site-packages\networkx\algorithms\centrality\betweenness.py in _accumulate_edges(betweenness, S, P, sigma, s)
#     315
#     316
# --> 317 def _accumulate_edges(betweenness, S, P, sigma, s):
#     318     delta = dict.fromkeys(S, 0)
#     319     while S:
#
# KeyboardInterrupt:

# %%
print("number of communities: ", len(communities))
print("number of people per communities: ")
for i in communities:
    print(len(i))

# %%
from networkx.algorithms import distance_measures
print(distance_measures.diameter(g))
# Out:
# 8

# %%
print(distance_measures.radius(g))
# Out:
# 4

# %%
import community

#first compute the best partition
partition = community.best_partition(g)

#drawing
size = float(len(set(partition.values())))
pos = nx.spring_layout(g)
count = 0.
for com in set(partition.values()) :
    count = count + 1.
    list_nodes = [nodes for nodes in partition.keys()
                                if partition[nodes] == com]
    nx.draw_networkx_nodes(g, pos, list_nodes, node_size = 20,
                                node_color = str(count / size))
print("Jumlah komunitas = ", count)

nx.draw_networkx_edges(g, pos, alpha=0.5)
plt.show()
# Out:
# Jumlah komunitas =  16.0
